# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaya9522/daily-practice/blob/main/UniAcco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_excel("/content/drive/MyDrive/DATA SET/Data_Science_Internship.xlsx")

# %%
df.head()
# Out:
#    Unnamed: 0                                           Agent_id status  \
# 0         0.0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# 1         1.0  299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...   LOST
# 2         2.0  c213697430c006013012dd2aca82dd9732aa0a1a6bca13...   LOST
# 3         3.0  eac9815a500f908736d303e23aa227f0957177b0e6756b...   LOST
# 4         4.0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
#
#       lost_reason                budget                                lease  \
# 0  Not responding                   NaN                                  NaN
# 1      Low budget                   NaN                                  NaN
# 2  Not responding  £121 - £180 Per Week  Full Year Course Stay 40 - 44 weeks
# 3      Low budget                   0-0                                  0.0
# 4       Junk lead                   NaN                                  NaN
#
#       movein                                             source  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46608 entries, 0 to 46607
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      46608 non-null  float64
#  1   Agent_id        46608 non-null  object
#  2   status          46608 non-null  object
#  3   lost_reason     43244 non-null  object
#  4   budget          42908 non-null  object
#  5   lease           44267 non-null  object
#  6   movein          32970 non-null  datetime64[ns]
#  7   source          46608 non-null  object
#  8   source_city     46608 non-null  object
#  9   source_country  46608 non-null  object
#  10  utm_source      46608 non-null  object
#  11  utm_medium      46608 non-null  object
#  12  des_city        46608 non-null  object
#  13  des_country     46608 non-null  object
#  14  room_type       23061 non-null  object
#  15  lead_id         46608 non-null  object
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0
# count  46608.00000
# mean   23303.50000
# std    13454.71501
# min        0.00000
# 25%    11651.75000
# 50%    23303.50000
# 75%    34955.25000
# max    46607.00000

# %%
df.shape
# Out:
# (46608, 16)

# %%
# Check for missing values

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0            0
# Agent_id              0
# status                0
# lost_reason        3364
# budget             3700
# lease              2341
# movein            13638
# source                0
# source_city           0
# source_country        0
# utm_source            0
# utm_medium            0
# des_city              0
# des_country           0
# room_type         23547
# lead_id               0
# dtype: int64

# %%
# Replace '9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6c9bc9d493a23be9de0' with NaN
df.replace('9b2d5b4678781e53038e91ea5324530a03f27dc1d0e5f6c9bc9d493a23be9de0', np.nan, inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0            0
# Agent_id              0
# status                0
# lost_reason        3364
# budget             3700
# lease              2341
# movein            13638
# source             5977
# source_city        8851
# source_country     8641
# utm_source           61
# utm_medium         3187
# des_city           2537
# des_country        2537
# room_type         23547
# lead_id               0
# dtype: int64

# %%
#replacing NaN to mode of lost_reason column

# %%
mode1=df['budget'].mode()
df['budget'].fillna(value=mode1[0], inplace=True)

# %%
mode2=df['lease'].mode()
df['lease'].fillna(value=mode2[0], inplace=True)

# %%
mode3=df['movein'].mode()
df['movein'].fillna(value=mode3[0], inplace=True)

# %%
mode4=df['source'].mode()
df['source'].fillna(value=mode4[0], inplace=True)

# %%
mode5=df['source_city'].mode()
df['source_city'].fillna(value=mode5[0], inplace=True)

# %%
mode6=df['source_country'].mode()
df['source_country'].fillna(value=mode6[0], inplace=True)

# %%
mode7=df['utm_source'].mode()
df['utm_source'].fillna(value=mode7[0], inplace=True)

# %%
mode8=df['utm_medium'].mode()
df['utm_medium'].fillna(value=mode8[0], inplace=True)

# %%
mode9=df['des_city'].mode()
df['des_city'].fillna(value=mode9[0], inplace=True)

# %%
mode10=df['des_country'].mode()
df['des_country'].fillna(value=mode10[0], inplace=True)

# %%
mode11=df['room_type'].mode()
df['room_type'].fillna(value=mode11[0], inplace=True)

# %%
df['lost_reason'].fillna('booking_happened', inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Unnamed: 0        0
# Agent_id          0
# status            0
# lost_reason       0
# budget            0
# lease             0
# movein            0
# source            0
# source_city       0
# source_country    0
# utm_source        0
# utm_medium        0
# des_city          0
# des_country       0
# room_type         0
# lead_id           0
# dtype: int64

# %%
df['status'].value_counts()
# Out:
# LOST           43244
# WON             3073
# OPPORTUNITY      254
# CONTACTED         28
# PROCESSING         8
# IMPORTANT          1
# Name: status, dtype: int64

# %%
df.shape
# Out:
# (46608, 16)

# %%
# Select rows where the 'status' column is not 'WON' or 'LOST'
mask = (df['status'] != 'WON') & (df['status'] != 'LOST')
rows_to_drop = df[mask].index

# %%
# Drop the selected rows from the DataFrame
df.drop(rows_to_drop, inplace=True)

# %%
df.shape
# Out:
# (46317, 16)

# %%
df.head()
# Out:
#    Unnamed: 0                                           Agent_id status  \
# 0         0.0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# 1         1.0  299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...   LOST
# 2         2.0  c213697430c006013012dd2aca82dd9732aa0a1a6bca13...   LOST
# 3         3.0  eac9815a500f908736d303e23aa227f0957177b0e6756b...   LOST
# 4         4.0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
#
#       lost_reason                budget                                lease  \
# 0  Not responding   £60 - £120 Per week  Full Year Course Stay 40 - 44 weeks
# 1      Low budget   £60 - £120 Per week  Full Year Course Stay 40 - 44 weeks
# 2  Not responding  £121 - £180 Per Week  Full Year Course Stay 40 - 44 weeks
# 3      Low budget                   0-0                                  0.0
# 4       Junk lead   £60 - £120 Per week  Full Year Course Stay 40 - 44 weeks
#
#       movein                                             source  \
# ...

# %%
df['lost_reason'].value_counts()
# Out:
# Low availability                  8892
# Not responding                    7827
# Not interested                    6449
# Low budget                        5505
# booking_happened                  3073
# Wants private accommodation       2781
# Short stay                        2264
# Not a student                     1518
# Just Enquiring                    1263
# Inadequate details                 827
# Semester stay                      817
# Booked with manager                676
# Junk lead                          629
# Booked on campus accommodation     613
# Supply issue                       538
# No supply                          534
# Not serving in that region         411
# Repeat lead                        394
# Booked with competitor             356
# Not going to university            329
# Distance issue                     219
# Junk lead/ Just Enquiring          147
# Lead issue                         127
# Looking for admission               41
# ...

# %%
df['budget'].value_counts()
# Out:
# £60 - £120 Per week     13444
# £121 - £180 Per Week     8878
# 0-0                      5719
# £181 - £240 Per Week     2143
# 100.0                    1512
#                         ...
# 1400-1500                   1
# 600-750pm                   1
# 0-Under 300                 1
# 0-Brunel University         1
# 0-500 PCM                   1
# Name: budget, Length: 1834, dtype: int64

# %%
DF1=df[df['status']=='LOST']

# %%
DF2=df[df['status']=='WON']

# %%
DF2[['status','lost_reason','budget']]
# Out:
#       status       lost_reason                budget
# 98       WON  booking_happened                 109.0
# 111      WON  booking_happened  £121 - £180 Per Week
# 139      WON  booking_happened  £181 - £240 Per Week
# 141      WON  booking_happened       > 300£ Per Week
# 152      WON  booking_happened  £121 - £180 Per Week
# ...      ...               ...                   ...
# 46559    WON  booking_happened                 139.0
# 46566    WON  booking_happened                 179.0
# 46570    WON  booking_happened                 180.0
# 46586    WON  booking_happened  £121 - £180 Per Week
# 46592    WON  booking_happened   £60 - £120 Per week
#
# [3073 rows x 3 columns]

# %%
DF1['lost_reason'].value_counts()
# Out:
# Low availability                  8892
# Not responding                    7827
# Not interested                    6449
# Low budget                        5505
# Wants private accommodation       2781
# Short stay                        2264
# Not a student                     1518
# Just Enquiring                    1263
# Inadequate details                 827
# Semester stay                      817
# Booked with manager                676
# Junk lead                          629
# Booked on campus accommodation     613
# Supply issue                       538
# No supply                          534
# Not serving in that region         411
# Repeat lead                        394
# Booked with competitor             356
# Not going to university            329
# Distance issue                     219
# Junk lead/ Just Enquiring          147
# Lead issue                         127
# Looking for admission               41
# Didn't respond in time              35
# ...

# %%
DF1['budget'].value_counts()
# Out:
# £60 - £120 Per week     12843
# £121 - £180 Per Week     8241
# 0-0                      5507
# £181 - £240 Per Week     2008
# 100.0                    1455
#                         ...
# 0-£129                      1
# 90-100£                     1
# 0-Max 425                   1
# 250 Per Week                1
# 0-500 PCM                   1
# Name: budget, Length: 1752, dtype: int64

# %%
df[['status','lost_reason','budget']]
# Out:
#       status       lost_reason                budget
# 0       LOST    Not responding   £60 - £120 Per week
# 1       LOST        Low budget   £60 - £120 Per week
# 2       LOST    Not responding  £121 - £180 Per Week
# 3       LOST        Low budget                   0-0
# 4       LOST         Junk lead   £60 - £120 Per week
# ...      ...               ...                   ...
# 46603   LOST  Low availability   £60 - £120 Per week
# 46604   LOST     Semester stay   £60 - £120 Per week
# 46605   LOST  Low availability  £241 - £300 Per week
# 46606   LOST  Low availability                1108.0
# 46607   LOST  Low availability  £181 - £240 Per Week
#
# [46317 rows x 3 columns]

# %%
# Use the 'apply()' method to assign the value 50 to any row where 'lost_reason' is 'Not available'
df['lost_won'] = df['status'].apply(lambda x: 0 if x == 'LOST' else 1)

# %%
df.head(5)
# Out:
#    Unnamed: 0                                           Agent_id status  \
# 0         0.0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# 1         1.0  299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...   LOST
# 2         2.0  c213697430c006013012dd2aca82dd9732aa0a1a6bca13...   LOST
# 3         3.0  eac9815a500f908736d303e23aa227f0957177b0e6756b...   LOST
# 4         4.0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
#
#       lost_reason                budget                                lease  \
# 0  Not responding   £60 - £120 Per week  Full Year Course Stay 40 - 44 weeks
# 1      Low budget   £60 - £120 Per week  Full Year Course Stay 40 - 44 weeks
# 2  Not responding  £121 - £180 Per Week  Full Year Course Stay 40 - 44 weeks
# 3      Low budget                   0-0                                  0.0
# 4       Junk lead   £60 - £120 Per week  Full Year Course Stay 40 - 44 weeks
#
#       movein                                             source  \
# ...

# %%
df['lost_reason'].value_counts()
# Out:
# Low availability                  8892
# Not responding                    7827
# Not interested                    6449
# Low budget                        5505
# booking_happened                  3073
# Wants private accommodation       2781
# Short stay                        2264
# Not a student                     1518
# Just Enquiring                    1263
# Inadequate details                 827
# Semester stay                      817
# Booked with manager                676
# Junk lead                          629
# Booked on campus accommodation     613
# Supply issue                       538
# No supply                          534
# Not serving in that region         411
# Repeat lead                        394
# Booked with competitor             356
# Not going to university            329
# Distance issue                     219
# Junk lead/ Just Enquiring          147
# Lead issue                         127
# Looking for admission               41
# ...

# %%
df[df['lost_reason']=='Low budget']
# Out:
#        Unnamed: 0                                           Agent_id status  \
# 1             1.0  299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...   LOST
# 3             3.0  eac9815a500f908736d303e23aa227f0957177b0e6756b...   LOST
# 8             8.0  ab6bb4584e9946b135dca2e39d12abba3ea82d5ea927d0...   LOST
# 14           14.0  a9f80b4eaba3fd134bafafe7506e08940201964615f7ee...   LOST
# 46           46.0  dcecd385d9a8aae54c55020d6c53aae1d7820982ac66d5...   LOST
# ...           ...                                                ...    ...
# 46557     46557.0  1dc43dab243ecfa3cc71b4fbc230ffd813798c72d1d551...   LOST
# 46569     46569.0  bf515bf88fb9df00a0e224fc4f6a7b4f88010444e8d056...   LOST
# 46575     46575.0  2306878a9ad9b57686cd623dd285aaa9b25afdf627f651...   LOST
# 46581     46581.0  c213697430c006013012dd2aca82dd9732aa0a1a6bca13...   LOST
# 46589     46589.0  9ab9b659a836589f715b72165b0d32cad846412e62851c...   LOST
#
#       lost_reason               budget  \
# ...

# %%
# Convert all columns to categorical columns
df = df.astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 46317 entries, 0 to 46607
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      46317 non-null  category
#  1   Agent_id        46317 non-null  category
#  2   status          46317 non-null  category
#  3   lost_reason     46317 non-null  category
#  4   budget          46317 non-null  category
#  5   lease           46317 non-null  category
#  6   movein          46317 non-null  category
#  7   source          46317 non-null  category
#  8   source_city     46317 non-null  category
#  9   source_country  46317 non-null  category
#  10  utm_source      46317 non-null  category
#  11  utm_medium      46317 non-null  category
#  12  des_city        46317 non-null  category
#  13  des_country     46317 non-null  category
#  14  room_type       46317 non-null  category
#  15  lead_id         46317 non-null  category
# dtypes: category(16)
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, confusion_matrix, roc_curve, auc

from sklearn import metrics  
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from sklearn.metrics import RocCurveDisplay 
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import PrecisionRecallDisplay
from sklearn.ensemble import RandomForestClassifier

# %%
df_ran=df.copy()

# %%
df_ran
# Out:
#        Unnamed: 0                                           Agent_id status  \
# 0             0.0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# 1             1.0  299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...   LOST
# 2             2.0  c213697430c006013012dd2aca82dd9732aa0a1a6bca13...   LOST
# 3             3.0  eac9815a500f908736d303e23aa227f0957177b0e6756b...   LOST
# 4             4.0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# ...           ...                                                ...    ...
# 46603     46603.0  2306878a9ad9b57686cd623dd285aaa9b25afdf627f651...   LOST
# 46604     46604.0  327ec29056cc47c24bf922f7dc0f78261dad5c726d7353...   LOST
# 46605     46605.0  1134c0a7d44fdae1afd7f1f64e2789496784095ca0a050...   LOST
# 46606     46606.0  8b8b029f1142f5cbc825aa6cbee01406c915c6b055db79...   LOST
# 46607     46607.0  1ea65ea38f2f574b3875ba895e4ff76b284b7725041612...   LOST
#
#             lost_reason                budget  \
# ...

# %%
#define the X and y value
X =df_ran.drop(['status','Agent_id','movein','source','source_city','source_country','utm_source','utm_medium','des_city','des_country','room_type','lead_id'],axis=1)
y = df_ran['status']

# %%
X
# Out:
#        Unnamed: 0       lost_reason                budget  \
# 0             0.0    Not responding   £60 - £120 Per week
# 1             1.0        Low budget   £60 - £120 Per week
# 2             2.0    Not responding  £121 - £180 Per Week
# 3             3.0        Low budget                   0-0
# 4             4.0         Junk lead   £60 - £120 Per week
# ...           ...               ...                   ...
# 46603     46603.0  Low availability   £60 - £120 Per week
# 46604     46604.0     Semester stay   £60 - £120 Per week
# 46605     46605.0  Low availability  £241 - £300 Per week
# 46606     46606.0  Low availability                1108.0
# 46607     46607.0  Low availability  £181 - £240 Per Week
#
#                                             lease
# 0             Full Year Course Stay 40 - 44 weeks
# 1             Full Year Course Stay 40 - 44 weeks
# 2             Full Year Course Stay 40 - 44 weeks
# 3                                             0.0
# ...

# %%
rf_clf = RandomForestClassifier()
rf_clf.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-193-ceb9b75eafe7> in <module>
#       1 rf_clf = RandomForestClassifier()
# ----> 2 rf_clf.fit(X_train,y_train)
#
# /usr/local/lib/python3.9/dist-packages/sklearn/ensemble/_forest.py in fit(self, X, y, sample_weight)
#     343         if issparse(y):
#     344             raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 345         X, y = self._validate_data(
#     346             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     347         )
#
# /usr/local/lib/python3.9/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     563                 y = check_array(y, input_name="y", **check_y_params)
#     564             else:
# --> 565                 X, y = check_X_y(X, y, **check_params)
# ...
